# %% [markdown]
# # Drones
#
# This Notebook contains all of the necessary and relevant theory pertaining to drones. The idea is simple. To model a simple X drone and to write code including Control loops that will enable the drone to hover comfortably. we have to track multiple inputs to control multiple outputs, therefore this is a MIMO operation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = x**2
plt.plot(x, y)
